# %% [markdown]
# <a href="https://colab.research.google.com/github/GovindSinghShekhawat/computer_vision/blob/main/ImageResizeInterpolation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np

# %%
img = cv2.imread('/colored_stones.jpg')

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=278x181 at 0x7FB5D15DCE48>

# %%
dimension = img.shape
dimension
# Out:
# (181, 278, 3)

# %%
res_img = cv2.resize(img, dsize=(556,362),interpolation=cv2.INTER_CUBIC)
cv2_imshow(res_img)
# Out:
# <PIL.Image.Image image mode=RGB size=556x362 at 0x7FB5D15F4208>
